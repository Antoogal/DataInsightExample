# %% [markdown]
# libraries used/needed

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df = pd.read_csv('sales_dataset.csv')
df
# Out:
#      marketing_budget(thousands)  actual_sales(millions)
# 0                         187.86                   12.14
# 1                         138.13                   12.33
# 2                         177.89                    8.41
# 3                         181.13                    8.90
# 4                         151.50                   12.57
# ..                           ...                     ...
# 217                       181.34                   10.60
# 218                       147.05                    9.01
# 219                       192.21                   11.90
# 220                       191.22                    8.36
# 221                       108.68                    9.07
#
# [222 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 222 entries, 0 to 221
# Data columns (total 2 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   marketing_budget(thousands)  222 non-null    float64
#  1   actual_sales(millions)       222 non-null    float64
# dtypes: float64(2)
# memory usage: 3.6 KB

# %% [markdown]
# summarize the statistical analysis

# %%
df.describe()
# Out:
#        marketing_budget(thousands)  actual_sales(millions)
# count                   222.000000              222.000000
# mean                    257.992883               16.083198
# std                      78.439312                4.638950
# min                     101.910000                8.010000
# 25%                     189.585000               12.445000
# 50%                     262.485000               15.560000
# 75%                     327.787500               19.310000
# max                     396.880000               25.980000

# %% [markdown]
# check for missing values

# %%
df.isnull().sum()
# Out:
# marketing_budget(thousands)    0
# actual_sales(millions)         0
# dtype: int64

# %% [markdown]
# No missing values
#
#
# Visualization in python

# %%
plt.figure(figsize = (10,6))
sns.regplot(data = df, x = 'marketing_budget(thousands)', y = 'actual_sales(millions)',
            scatter_kws={'color':'green'})
plt.title('Correlation between Marketing Budget and Actual Sales', fontsize = 16, fontweight = 'bold')
plt.grid(False)
plt.show()

# %% [markdown]
# Conclusion
#
# A linear regression analysis between marketing budget and actual sales reveals a strong positive correlation. Indicating that increasing the marketing budget, increases actual sales.
